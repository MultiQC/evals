# %% [markdown]
# ### Generate real-life and simulated runs

# %% [markdown]
# Simulating runs. We'd like to stress-test potential data lakes of thousands of runs and millions of samples. We don't have real data handly, but can try simulate those.

# %%
import os
import random
import string
from datetime import datetime, timedelta
import json
from pathlib import Path
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
from cloudpathlib import S3Path

# %%
NUM_RUNS = 10
NUM_MODULES = 10
NUM_SECTIONS_PER_MODULE = 5
NUM_SAMPLES_PER_MODULE = 10
NUM_METRICS_PER_MODULE = 20

# Paths
PARQUET_BUCKET = S3Path("s3://megaqc-test/simulated/")
# PARQUET_BUCKET = Path("./data")

# Parquet setup
dir_name = f"{NUM_RUNS}runs_{NUM_MODULES}mod_{NUM_SAMPLES_PER_MODULE}samples_{NUM_METRICS_PER_MODULE}metrics"
target_path = PARQUET_BUCKET / dir_name


def generate_random_string(length=10):
    """Generate a random string of fixed length"""
    return "".join(random.choices(string.ascii_letters, k=length))


def generate_metric_metadata():
    """Generate metadata for a metric"""
    return {
        "min": random.uniform(0, 10),
        "max": random.uniform(90, 100),
        "dmin": random.uniform(0, 3),
        "dmax": random.uniform(9, 10),
        "scale": random.choice(["Set2", "Accent", "Set1", "Set3", "Dark2", "Paired", "Pastel2", "Pastel1"]),
        "color": f"#{random.randint(0, 0xFFFFFF):06x}",
        "type": random.choice(["numeric", "categorical", "percentage"]),
        "namespace": generate_random_string(10),
        "placement": random.randint(0, 1000),
        "shared_key": random.choice(["read_count", "base_count"]),
    }


def generate_value_metadata(value):
    """Generate metadata for a value"""
    return {
        "val_raw": value,
        "val_raw_type": random.choice(["int", "float", "str"]),
        "val_mod": value,
        "val_mod_type": random.choice(["int", "float", "str"]),
        "val_fmt": f"{value:.2f}" if isinstance(value, float) else str(value),
    }


def generate_sample_data(num_metrics):
    """Generate data for a single sample"""
    sample_id = generate_random_string()
    metrics = {}

    for i in range(num_metrics):
        metric_name = f"metric_{i}"
        value = random.uniform(0, 100)
        metrics[metric_name] = generate_value_metadata(value),

    return {"sample_id": sample_id, "metrics": metrics}


def generate_module_data(module_index, num_samples, num_metrics, num_sections):
    """Generate data for a single module"""
    samples = [generate_sample_data(num_metrics) for _ in range(num_samples)]
    sections = [generate_section_data() for _ in range(num_sections)]

    metrics_metadata = {}
    for i in range(num_metrics):
        metric_name = f"metric_{i}"
        metrics_metadata[metric_name] = generate_metric_metadata()

    return {
        "module_id": f"module_{module_index}",
        "name": f"Module {module_index}",
        "url": f"http://example.com/module/{module_index}",
        "comment": f"This is module {module_index}",
        "metrics_metadata": metrics_metadata,
        "samples": samples,
        "sections": sections,
        "anchor": f"anchor_{module_index}",
        "doi": generate_random_string(20),
    }


def generate_section_data():
    """Generate data for a section"""
    section_id = generate_random_string()
    anchor = f"section_{section_id}"
    
    return {
        "name": f"Section {section_id}",
        "anchor": anchor,
        "id": section_id,
        "description": f"Description for section {section_id}",
        "module": f"module_{random.randint(0,100)}",
        "module_anchor": f"module_anchor_{random.randint(0,100)}",
        "module_info": f"Info about module for section {section_id}",
        "comment": f"Comment for section {section_id}",
        "helptext": f"Help text for section {section_id}",
        "content_before_plot": f"Content before plot for section {section_id}",
        "content": f"Main content for section {section_id}",
        "plot": f"Plot content for section {section_id}",
        "print_section": random.choice([True, False]),
        "plot_anchor": f"plot_{section_id}" if random.choice([True, False]) else None,
        "ai_summary": f"AI generated summary for section {section_id}"
    }


def generate_run_data(
    run_index, num_modules, num_samples_per_module, num_metrics_per_module, num_sections_per_module
):
    """Generate data for a single run"""
    modules = [
        generate_module_data(i, num_samples_per_module, num_metrics_per_module, num_sections_per_module)
        for i in range(num_modules)
    ]

    return {
        "run_id": f"run_{run_index}",
        "timestamp": (datetime.now() - timedelta(days=random.randint(0, 100))).isoformat(),
        "modules": modules,
    }

# %%
def flatten_hierarchical_data(run):
    """Convert hierarchical data to flat format for Parquet
    
    Args:
        data: Nested JSON-like data with runs, modules, samples, and metrics
        
    Returns:
        pd.DataFrame: Flattened dataframe with one row per metric value
    """
    flat_records = []

    run_id = run["run_id"]
    timestamp = run["timestamp"]

    for module in run["modules"]:
        module_id = module["module_id"]
        module_name = module["name"]
        module_url = module["url"]
        module_comment = module["comment"]
        module_anchor = module.get("anchor", "")
        module_doi = module.get("doi", "")
        
        # Extract metrics metadata for later use
        metrics_metadata = module.get("metrics_metadata", {})
        
        # Process samples data
        for sample in module["samples"]:
            sample_id = sample["sample_id"]

            for metric_name, metric_data in sample["metrics"].items():
                # The metric_data is a tuple with one element in your generator
                metric_values = metric_data[0] if isinstance(metric_data, tuple) else metric_data

                flat_records.append({
                    # Run information
                    "run_id": run_id,
                    "timestamp": timestamp,
                    
                    # Module information
                    "module_id": module_id,
                    "module_name": module_name,
                    "module_url": module_url,
                    "module_comment": module_comment,
                    "module_anchor": module_anchor,
                    "module_doi": module_doi,
                    
                    # Sample information
                    "sample_id": sample_id,
                    
                    # Metric information
                    "metric_name": metric_name,
                    
                    # Value metadata
                    "val_raw": metric_values.get("val_raw"),
                    "val_raw_type": metric_values.get("val_raw_type"),
                    "val_mod": metric_values.get("val_mod"),
                    "val_mod_type": metric_values.get("val_mod_type"),
                    "val_fmt": metric_values.get("val_fmt"),
                    
                    # Metric metadata (from module)
                    "metric_min": metrics_metadata.get(metric_name, {}).get("min"),
                    "metric_max": metrics_metadata.get(metric_name, {}).get("max"),
                    "metric_dmin": metrics_metadata.get(metric_name, {}).get("dmin"),
                    "metric_dmax": metrics_metadata.get(metric_name, {}).get("dmax"),
                    "metric_scale": metrics_metadata.get(metric_name, {}).get("scale"),
                    "metric_color": metrics_metadata.get(metric_name, {}).get("color"),
                    "metric_type": metrics_metadata.get(metric_name, {}).get("type"),
                    "metric_namespace": metrics_metadata.get(metric_name, {}).get("namespace"),
                    "metric_placement": metrics_metadata.get(metric_name, {}).get("placement"),
                    "metric_shared_key": metrics_metadata.get(metric_name, {}).get("shared_key"),
                })
        
        # Process sections data
        for section in module.get("sections", []):
            section_id = section.get("id", "")
            section_name = section.get("name", "")
            section_anchor = section.get("anchor", "")
            
            flat_records.append({
                # Run information
                "run_id": run_id,
                "timestamp": timestamp,
                
                # Module information
                "module_id": module_id,
                "module_name": module_name,
                
                # Section information (no sample or metric)
                "entity_type": "section",
                "section_id": section_id,
                "section_name": section_name,
                "section_anchor": section_anchor,
                "section_description": section.get("description", ""),
                "section_module": section.get("module", ""),
                "section_module_anchor": section.get("module_anchor", ""),
                "section_module_info": section.get("module_info", ""),
                "section_comment": section.get("comment", ""),
                "section_helptext": section.get("helptext", ""),
                "section_content_before_plot": section.get("content_before_plot", ""),
                "section_content": section.get("content", ""),
                "section_plot": section.get("plot", ""),
                "section_print_section": section.get("print_section", False),
                "section_plot_anchor": section.get("plot_anchor", ""),
                "section_ai_summary": section.get("ai_summary", ""),
            })

    # Convert to DataFrame
    df = pd.DataFrame(flat_records)
    
    # Add entity_type for sample metrics if not already set
    if "entity_type" in df.columns:
        df.loc[df["entity_type"].isna(), "entity_type"] = "sample_metric"
    else:
        df["entity_type"] = "sample_metric"
        
    return df

# %%
json_dir = target_path / "json"
parquet_dir = target_path / "parquet"
json_dir.mkdir(parents=True, exist_ok=True)
parquet_dir.mkdir(parents=True, exist_ok=True)

for run_number in range(NUM_RUNS):
    data = generate_run_data(
        run_number, NUM_MODULES, NUM_SAMPLES_PER_MODULE, NUM_METRICS_PER_MODULE, NUM_SECTIONS_PER_MODULE
    )
    # Save to JSON
    # with (json_dir / f"run_{run_number}.json").open("w") as f:
    #     json.dump(data, f)

    df = flatten_hierarchical_data(data)
    df.to_parquet(str(parquet_dir / f"run_{run_number}.parquet"))

# %% [markdown]
# Generating real-life runs

# %%
import math
from collections import defaultdict

# List files in the directory
fastqc_dir = "/Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc"
report_files = os.listdir(fastqc_dir)

# Extract sample names (e.g., ERX1120885)
sample_pattern = r'(ERX\d+)\_fastqc\.zip'
paths = []
for file in report_files:
    paths.append(file)

# Sort samples to ensure consistent grouping
paths.sort()

# Calculate roughly how many samples per group (aiming for 8 groups)
num_groups = 8
samples_per_group = math.ceil(len(paths) / num_groups)

# Create the groups
sample_groups = defaultdict(list)
for i, path in enumerate(paths):
    group_idx = i // samples_per_group
    sample_groups[f"group_{group_idx+1}"].append(fastqc_dir + "/" + path)

# Generate glob patterns for each group
group_patterns = {}
for i, (group_name, group_samples) in enumerate(sample_groups.items()):    
    print(f"multiqc -o tmp/runs/run{i + 1} -f --strict {' '.join(group_samples)}")
# Out:
# multiqc -o tmp/runs/run1 -f --strict /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120885_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120886_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120887_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120888_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120889_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120890_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120891_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120892_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120893_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120894_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120895_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120896_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120897_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120898_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120899_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120900_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120901_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120902_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120903_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120904_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120905_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120906_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120907_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120908_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120909_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120910_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120911_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120912_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120913_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120914_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120915_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120916_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120917_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120918_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120919_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120920_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120921_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120922_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120923_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120924_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120925_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120926_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120927_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120928_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1120929_fastqc.zip /Us ...
# multiqc -o tmp/runs/run2 -f --strict /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121077_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121078_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121079_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121080_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121081_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121082_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121083_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121084_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121085_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121086_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121087_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121088_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121089_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121090_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121091_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121092_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121093_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121094_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121095_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121096_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121097_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121098_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121099_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121100_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121101_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121102_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121103_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121104_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121105_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121106_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121107_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121108_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121109_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121110_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121111_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121112_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121113_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121114_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121115_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121116_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121117_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121118_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121119_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121120_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121121_fastqc.zip /Us ...
# multiqc -o tmp/runs/run3 -f --strict /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121269_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121270_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121271_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121272_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121273_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121274_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121275_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121276_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121277_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121278_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121279_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121280_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121281_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121282_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121283_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121284_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121285_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121286_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121287_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121288_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121289_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121290_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121291_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121292_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121293_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121294_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121295_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121296_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121297_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121298_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121299_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121300_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121301_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121302_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121303_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121304_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121305_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121306_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121307_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121308_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121309_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121310_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121311_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121312_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121313_fastqc.zip /Us ...
# multiqc -o tmp/runs/run4 -f --strict /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121461_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121462_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121463_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121464_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121465_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121466_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121467_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121468_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121469_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121470_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121471_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121472_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121473_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121474_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121475_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121476_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121477_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121478_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121479_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121480_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121481_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121482_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121483_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121484_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121485_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121486_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121487_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121488_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121489_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121490_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121491_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121492_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121493_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121494_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121495_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121496_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121497_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121498_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121499_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121500_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121501_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121502_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121503_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121504_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121505_fastqc.zip /Us ...
# multiqc -o tmp/runs/run5 -f --strict /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121653_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121654_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121655_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121656_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121657_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121658_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121659_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121660_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121661_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121662_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121663_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121664_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121665_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121666_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121667_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121668_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121669_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121670_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121671_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121672_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121673_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121674_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121675_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121676_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121677_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121678_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121679_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121680_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121681_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121682_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121683_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121684_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121685_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121686_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121687_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121688_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121689_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121690_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121691_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121692_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121693_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121694_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121695_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121696_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121697_fastqc.zip /Us ...
# multiqc -o tmp/runs/run6 -f --strict /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121845_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121846_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121847_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121848_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121849_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121850_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121851_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121852_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121853_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121854_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121855_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121856_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121857_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121858_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121859_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121860_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121861_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121862_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121863_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121864_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121865_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121866_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121867_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121868_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121869_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121870_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121871_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121872_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121873_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121874_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121875_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121876_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121877_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121878_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121879_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121880_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121881_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121882_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121883_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121884_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121885_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121886_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121887_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121888_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1121889_fastqc.zip /Us ...
# multiqc -o tmp/runs/run7 -f --strict /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122037_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122038_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122039_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122040_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122041_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122042_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122043_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122044_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122045_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122046_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122047_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122048_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122049_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122050_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122051_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122052_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122053_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122054_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122055_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122056_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122057_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122058_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122059_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122060_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122061_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122062_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122063_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122064_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122065_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122066_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122067_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122068_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122069_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122070_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122071_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122072_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122073_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122074_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122075_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122076_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122077_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122078_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122079_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122080_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122081_fastqc.zip /Us ...
# multiqc -o tmp/runs/run8 -f --strict /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122229_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122230_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122231_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122232_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122233_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122234_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122235_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122236_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122237_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122238_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122239_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122240_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122241_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122242_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122243_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122244_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122245_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122246_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122247_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122248_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122249_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122250_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122251_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122252_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122253_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122254_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122255_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122256_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122257_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122258_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122259_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122260_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122261_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122262_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122263_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122264_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122265_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122266_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122267_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122268_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122269_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122270_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122271_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122272_fastqc.zip /Users/vlad/Seqera/multiqc_heavy_examples/Petropoulus_2016/fastqc/ERX1122273_fastqc.zip /Us ...
